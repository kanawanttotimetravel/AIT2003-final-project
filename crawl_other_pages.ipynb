# %%
import pandas as pd
from facebook_scraper import get_profile
import time

# %%
page_lists = pd.read_csv('Data/pages.csv')['0'].to_list()
page_lists
# Out:
# ['NASAPersevere',
#  'NASAWebb',
#  'ISS',
#  'NASAHubble',
#  'NASAAstronauts',
#  'chandraxrayobservatory',
#  'NASAKennedy',
#  'spotifyusa',
#  'NASAEuropaClipper',
#  'NASAJSC',
#  'EuropeanSpaceAgency',
#  'MarsCuriosity',
#  'NasaAstrobiology',
#  'NASASolarSystem',
#  'NASAExoplanets',
#  'NASATechnology',
#  'NASAUniverse',
#  'Boeing',
#  'NASAInterns',
#  'observethemoon',
#  'NASAArtemis',
#  'nasaearth',
#  'NSIDC',
#  'USPS',
#  'NASAOrion',
#  'NASAes',
#  'thirdrockradionasa',
#  'janegoodallinst',
#  'spaceappschallenge',
#  'jaxa.en',
#  'NASAWFF',
#  'photo.php',
#  'NASASTEMEngagement',
#  'NOAA',
#  'NASAClimateChange',
#  'InternationalAstronomicalUnion',
#  'ISSNATIONALLAB',
#  'NASAJPL',
#  'NASAGoddard',
#  'NASAaero',
#  'NASAMoon',
#  'DoNASAScience',
#  'SpaceCenterHouston',
#  'nasaames',
#  'NASASLS',
#  'RocketLabUSA',
#  'ED.gov',
#  'NASARoman',
#  'blueorigin',
#  'NASAHistoryOffice']

# %%
profile_list = []
for page in page_lists:
    try:
        profile = get_profile(page, cookies='cookies.txt')
        profile_list.append(profile)
    except Exception as e:
        print(e)
    time.sleep(30)
# Out:
# F:\anaconda3\lib\site-packages\facebook_scraper\facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# Content not found

# %%
profile_df = pd.DataFrame(profile_list)
profile_df
# Out:
#    Friend_count Follower_count  Following_count  \
# 0          None           None              1.0
# 1          None           None             30.0
# 2          None           None             58.0
# 3          None           None             34.0
# 4          None           None             58.0
# 5          None           None             65.0
# 6          None           None             67.0
# 7          None           None              NaN
# 8          None           None              NaN
# 9          None           None              NaN
# 10         None           None              NaN
# 11         None           None              NaN
# 12         None           None              NaN
# 13         None           None              NaN
# 14         None           None              NaN
# 15         None           None              NaN
# 16         None           None              NaN
# 17         None           None              NaN
# ...

# %%
profile_df.to_csv('Data/pages_info.csv')
